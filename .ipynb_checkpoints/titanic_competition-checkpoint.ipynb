# %% [markdown]
# <h1>Check and Merge Data Set</h1><br>
# data Pre-Processing

# %%
import pandas as pd
import numpy as np

test_set = pd.read_csv('test.csv')
train_set = pd.read_csv('train.csv')

gender_submission = pd.read_csv('gender_submission.csv')
test_set = pd.merge(test_set, gender_submission, how='inner', on='PassengerId')

# Resorting Columns
c_num1 = test_set.columns[0:1].to_list()   # PassengerId
c_num2 = test_set.columns[-1:].to_list()     # Survived
c_others = test_set.columns[1:-1].to_list()   # rest columns

# resort
test_set = test_set[c_num1+c_num2+c_others]

print('test_set')
display(test_set)

print('\n\ntrain_set')
display(train_set)
# Out:
# test_set
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
# Check Correlation

corr = train_set.corr().abs().nlargest(3, 'Survived').drop('Survived')['Survived']
display(corr)
# Result : Pclass(0.338481), Fare(0.257307)

# Set train set
x = pd.DataFrame(np.c_[train_set[corr.index[0]], train_set[corr.index[1]]], columns = ['Pclass','Fare'])
y = train_set['Survived']

print(x)

# Visualize with Scatter Plot

import matplotlib.pyplot as plt

# Pclass vs Survived
plt.subplot(121)  # 1행 2열 1번차트
plt.scatter(x.iloc[:,0], y)
plt.xlabel("Pclass")
plt.ylabel("Survived")
plt.title("Pclass vs Survived")

# Fare vs Survived
plt.subplot(122)  # 1행 2열 2번차트
plt.scatter(x.iloc[:,1], y)
plt.xlabel("Fare")
plt.ylabel("Survived")
plt.title("Fare vs Survived")
plt.show()
# Out:
# Pclass    0.338481
# Fare      0.257307
# Name: Survived, dtype: float64
#      Pclass     Fare
# 0       3.0   7.2500
# 1       1.0  71.2833
# 2       3.0   7.9250
# 3       1.0  53.1000
# 4       3.0   8.0500
# ..      ...      ...
# 886     2.0  13.0000
# 887     1.0  30.0000
# 888     3.0  23.4500
# 889     1.0  30.0000
# 890     3.0   7.7500
#
# [891 rows x 2 columns]

# %% [markdown]
# <h2>Logistic Regression</h2>

# %%
from sklearn import linear_model

# Logistic Regression
log_regress = linear_model.LogisticRegression()
log_regress.fit(X = x, y = y)

print('\n--Logistic Modeling--')
print('Logistic Intercept:',log_regress.intercept_[0])
print('Logistic Coefficient:',log_regress.coef_[0][0])


# drop NaN included data(1)
test = pd.DataFrame(np.c_[test_set['Pclass'], test_set['Fare'],test_set['Survived']],columns = ['Pclass','Fare','Survived']).dropna()

# Predict with test data set
preds = log_regress.predict(test[['Pclass','Fare']])

#---generate table of predictions vs actual---
print("---Confusion Matrix---")
print(pd.crosstab(res, test['Survived']))

#---get the accuracy of the prediction---
print("---Accuracy---")
print(log_regress.score(X = test[['Pclass','Fare']], y = test['Survived']))

from sklearn import metrics

# View summary of common classification metrics
print("---Metrices---")
print(metrics.classification_report(y_true = test['Survived'], y_pred = preds))
# Out:
# --Logistic Modeling--
# Logistic Intercept: 0.8768391758013131
# Logistic Coefficient: -0.6762530777906535
# ---Confusion Matrix---
# Survived  0.0  1.0
# row_0
# 0         208  102
# 1          57   50
# ---Accuracy---
# 0.6187050359712231
# ---Metrices---
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.78      0.72       265
#          1.0       0.47      0.33      0.39       152
#
#     accuracy                           0.62       417
#    macro avg       0.57      0.56      0.55       417
# weighted avg       0.60      0.62      0.60       417
